# %% [markdown]
# # EBAC - Regressão II - regressão múltipla
#
# ## Tarefa I

# %% [markdown]
# #### Previsão de renda
#
# Vamos trabalhar com a base 'previsao_de_renda.csv', que é a base do seu próximo projeto. Vamos usar os recursos que vimos até aqui nesta base.
#
# |variavel|descrição|
# |-|-|
# |data_ref                | Data de referência de coleta das variáveis |
# |index                   | Código de identificação do cliente|
# |sexo                    | Sexo do cliente|
# |posse_de_veiculo        | Indica se o cliente possui veículo|
# |posse_de_imovel         | Indica se o cliente possui imóvel|
# |qtd_filhos              | Quantidade de filhos do cliente|
# |tipo_renda              | Tipo de renda do cliente|
# |educacao                | Grau de instrução do cliente|
# |estado_civil            | Estado civil do cliente|
# |tipo_residencia         | Tipo de residência do cliente (própria, alugada etc)|
# |idade                   | Idade do cliente|
# |tempo_emprego           | Tempo no emprego atual|
# |qt_pessoas_residencia   | Quantidade de pessoas que moram na residência|
# |renda                   | Renda em reais|

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import statsmodels.api as sm
import patsy
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
df = pd.read_csv('previsao_de_renda.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             15000 non-null  int64
#  1   data_ref               15000 non-null  object
#  2   id_cliente             15000 non-null  int64
#  3   sexo                   15000 non-null  object
#  4   posse_de_veiculo       15000 non-null  bool
#  5   posse_de_imovel        15000 non-null  bool
#  6   qtd_filhos             15000 non-null  int64
#  7   tipo_renda             15000 non-null  object
#  8   educacao               15000 non-null  object
#  9   estado_civil           15000 non-null  object
#  10  tipo_residencia        15000 non-null  object
#  11  idade                  15000 non-null  int64
#  12  tempo_emprego          12427 non-null  float64
#  13  qt_pessoas_residencia  15000 non-null  float64
#  14  renda                  15000 non-null  float64
# dtypes: bool(2), float64(3), int64(4), object(6)
# memory usage: 1.5+ MB

# %% [markdown]
# 1. Ajuste um modelo para prever log(renda) considerando todas as covariáveis disponíveis.
#     - Utilizando os recursos do Patsy, coloque as variáveis qualitativas como *dummies*.
#     - Mantenha sempre a categoria mais frequente como casela de referência
#     - Avalie os parâmetros e veja se parecem fazer sentido prático.
#
# 2. Remova a variável menos significante e analise:
#     - Observe os indicadores que vimos, e avalie se o modelo melhorou ou piorou na sua opinião.
#     - Observe os parâmetros e veja se algum se alterou muito.
#
# 3. Siga removendo as variáveis menos significantes, sempre que o *p-value* for menor que 5%. Compare o modelo final com o inicial. Observe os indicadores e conclua se o modelo parece melhor.

# %% [markdown]
# <h3 style="color:green">Limpeza inicial dos dados</h3>

# %%
df.drop(columns=['Unnamed: 0', 'data_ref', 'id_cliente'], inplace=True)

# %%
df.isna().sum()
# Out:
# sexo                        0
# posse_de_veiculo            0
# posse_de_imovel             0
# qtd_filhos                  0
# tipo_renda                  0
# educacao                    0
# estado_civil                0
# tipo_residencia             0
# idade                       0
# tempo_emprego            2573
# qt_pessoas_residencia       0
# renda                       0
# dtype: int64

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of       sexo  posse_de_veiculo  posse_de_imovel  qtd_filhos        tipo_renda  \
# 0        F             False             True           0        Empresário
# 1        M              True             True           0       Assalariado
# 2        F              True             True           0        Empresário
# 3        F             False             True           1  Servidor público
# 4        M              True            False           0       Assalariado
# ...    ...               ...              ...         ...               ...
# 14995    F             False             True           0        Empresário
# 14996    F             False             True           0       Pensionista
# 14997    F              True             True           0       Assalariado
# 14998    M              True            False           0        Empresário
# 14999    F             False             True           2  Servidor público
#
#                 educacao estado_civil tipo_residencia  idade  tempo_emprego  \
# 0             Secundário     Solteiro            Casa     26       6.602740
# 1      Superior completo       Casado            Casa     28       7.183562
# 2      Superior completo       Casado            Casa     35       0.838356
# 3      Superior completo       Casado            Casa     30       4.846575
# 4             Secundário     Solteiro   Governamental     33       4.293151
# ...                  ...          ...             ...    ...            ...
# 14995         Secundário     Solteiro            Casa     48      13.887671
# 14996  Superior completo     Solteiro            Casa     57            NaN
# 14997  Superior completo       Casado            Casa     45       7.832877
# 14998  Superior completo       Casado            Casa     36       4.298630
# 14999         Secundário        União            Casa     34       7.219178
#
#        qt_pessoas_residencia     renda
# 0                        1.0   8060.34
# 1                        2.0   1852.15
# 2                        2.0   2253.89
# 3                        3.0   6600.77
# 4                        1.0   6475.97
# ...                      ...       ...
# 14995                    1.0   7990.58
# 14996                    1.0  10093.45
# 14997                    2.0    604.82
# 14998                    2.0   3352.27
# 14999                    4.0   1160.99
#
# [15000 rows x 12 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   sexo                   15000 non-null  object
#  1   posse_de_veiculo       15000 non-null  bool
#  2   posse_de_imovel        15000 non-null  bool
#  3   qtd_filhos             15000 non-null  int64
#  4   tipo_renda             15000 non-null  object
#  5   educacao               15000 non-null  object
#  6   estado_civil           15000 non-null  object
#  7   tipo_residencia        15000 non-null  object
#  8   idade                  15000 non-null  int64
#  9   tempo_emprego          12427 non-null  float64
#  10  qt_pessoas_residencia  15000 non-null  float64
#  11  renda                  15000 non-null  float64
# dtypes: bool(2), float64(3), int64(2), object(5)
# memory usage: 1.2+ MB

# %% [markdown]
# <h3 style="color:green">Avaliando as covariáveis e treinando o modelo</h3>

# %%
y, x = patsy.dmatrices('np.log(renda) ~ C(sexo) + C(posse_de_veiculo) + C(posse_de_imovel) + qtd_filhos + C(tipo_renda) + C(educacao) + C(estado_civil) + C(tipo_residencia) + idade + tempo_emprego + C(qt_pessoas_residencia)'
                       , data = df)

# %%
reg = sm.OLS(y, x).fit()

# %%
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          np.log(renda)   R-squared:                       0.358
# Model:                            OLS   Adj. R-squared:                  0.357
# Method:                 Least Squares   F-statistic:                     223.2
# Date:                Fri, 07 Jun 2024   Prob (F-statistic):               0.00
# Time:                        14:24:31   Log-Likelihood:                -13560.
# No. Observations:               12427   AIC:                         2.718e+04
# Df Residuals:                   12395   BIC:                         2.742e+04
# Df Model:                          31
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               6.8671      0.144     47.651      0.000       6.585       7.150
# C(sexo)[T.M]                            0.7877      0.015     53.667      0.000       0.759       0.817
# C(posse_de_veiculo)[T.True]             0.0436      0.014      3.085      0.002       0.016       0.071
# C(posse_de_imovel)[T.True]              0.0829      0.014      5.917      0.000       0.055       0.110
# C(tipo_renda)[T.Bolsista]               0.2256      0.241      0.936      0.349      -0.247       0.698
# C(tipo_renda)[T.Empresário]             0.1550      0.015     10.381      0.000       0.126       0.184
# C(tipo_renda)[T.Pensionista]           -0.3098      0.241     -1.284      0.199      -0.783       0.163
# C(tipo_renda)[T.Servidor público]       0.0552      0.022      2.481      0.013       0.012       0.099
# C(educacao)[T.Pós graduação]            0.1059      0.159      0.665      0.506      -0.206       0.418
# C(educacao)[T.Secundário]              -0.0131      0.072     -0.181      0.856      -0.154       0.128
# C(educacao)[T.Superior completo]        0.0939      0.072      1.300      0.194      -0.048       0.236
# C(educacao)[T.Superior incompleto]     -0.0421      0.078     -0.541      0.588      -0.195       0.110
# C(estado_civil)[T.Separado]             0.3283      0.111      2.949      0.003       0.110       0.547
# C(estado_civil)[T.Solteiro]             0.2665      0.109      2.437      0.015       0.052       0.481
# C(estado_civil)[T.União]               -0.0339      0.025     -1.346      0.178      -0.083       0.015
# C(estado_civil)[T.Viúvo]                0.3652      0.116      3.144      0.002       0.138       0.593
# C(tipo_residencia)[T.Casa]             -0.0424      0.054     -0.782      0.434      -0.149       0.064
# C(tipo_residencia)[T.Com os pais]      -0.0234      0.060     -0.388      0.698      -0.142       0.095
# C(tipo_residencia)[T.Comunitário]      -0.1179      0.106     -1.112      0.266      -0.326       0.090
# C(tipo_residencia)[T.Estúdio]           0.0659      0.099      0.663      0.507      -0.129       0.261
# C(tipo_residencia)[T.Governamental]    -0.0537      0.066     -0.814      0.416      -0.183       0.076
# C(qt_pessoas_residencia)[T.2.0]         0.2825      0.109      2.585      0.010       0.068       0.497
# C(qt_pessoas_residencia)[T.3.0]         0.5961      0.216      2.761      0.006       0.173       1.019
# C(qt_pessoas_residencia)[T.4.0]         0.9014      0.324      2.784      0.005       0.267       1.536
# C(qt_pessoas_residencia)[T.5.0]         1.0405      0.435      2.391      0.017       0.188       1.893
# C(qt_pessoas_residencia)[T.6.0]         1.7297      0.567      3.052      0.002       0.619       2.841
# C(qt_pessoas_residencia)[T.7.0]         1.9420      0.975      1.992      0.046       0.031       3.853
# C(qt_pessoas_residencia)[T.9.0]         2.1947      0.925      2.373      0.018       0.381       4.008
# C(qt_pessoas_residencia)[T.15.0]        3.0822      1.607      1.918      0.055      -0.067       6.231
# qtd_filhos                             -0.2669      0.109     -2.450      0.014      -0.480      -0.053
# idade                                   0.0056      0.001      6.897      0.000       0.004       0.007
# tempo_emprego                           0.0616      0.001     59.268      0.000       0.060       0.064
# ==============================================================================
# Omnibus:                        1.118   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.572   Jarque-Bera (JB):                1.092
# Skew:                           0.021   Prob(JB):                        0.579
# Kurtosis:                       3.017   Cond. No.                     1.38e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.38e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# <h3 style="color:green">Agora vamos alterar as caselas de referência para as categorias mais frequentes e ver se algo muda com relação à qualidade do nosso modelo</h3>

# %%
df['sexo'].value_counts()
# Out:
# sexo
# F    10119
# M     4881
# Name: count, dtype: int64

# %%
df['posse_de_veiculo'].value_counts()
# Out:
# posse_de_veiculo
# False    9140
# True     5860
# Name: count, dtype: int64

# %%
df['posse_de_imovel'].value_counts()
# Out:
# posse_de_imovel
# True     10143
# False     4857
# Name: count, dtype: int64

# %%
df['tipo_renda'].value_counts()
# Out:
# tipo_renda
# Assalariado         7633
# Empresário          3508
# Pensionista         2582
# Servidor público    1268
# Bolsista               9
# Name: count, dtype: int64

# %%
df['educacao'].value_counts()
# Out:
# educacao
# Secundário             8895
# Superior completo      5335
# Superior incompleto     579
# Primário                165
# Pós graduação            26
# Name: count, dtype: int64

# %%
df['estado_civil'].value_counts()
# Out:
# estado_civil
# Casado      10534
# Solteiro     1798
# União        1078
# Separado      879
# Viúvo         711
# Name: count, dtype: int64

# %%
df['tipo_residencia'].value_counts()
# Out:
# tipo_residencia
# Casa             13532
# Com os pais        675
# Governamental      452
# Aluguel            194
# Estúdio             83
# Comunitário         64
# Name: count, dtype: int64

# %%
df['qt_pessoas_residencia'].value_counts()
# Out:
# qt_pessoas_residencia
# 2.0     8181
# 1.0     2752
# 3.0     2551
# 4.0     1311
# 5.0      179
# 6.0       18
# 9.0        5
# 15.0       2
# 7.0        1
# Name: count, dtype: int64

# %%
y, x = patsy.dmatrices('np.log(renda) ~ C(sexo, Treatment(1)) + C(posse_de_veiculo, Treatment(1)) + C(posse_de_imovel) + qtd_filhos + C(tipo_renda) + C(educacao, Treatment(2)) + C(estado_civil) + C(tipo_residencia, Treatment(0)) + idade + tempo_emprego + C(qt_pessoas_residencia, Treatment(2))'
                       , data = df)

# %%
reg = sm.OLS(y, x).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          np.log(renda)   R-squared:                       0.358
# Model:                            OLS   Adj. R-squared:                  0.357
# Method:                 Least Squares   F-statistic:                     223.2
# Date:                Fri, 07 Jun 2024   Prob (F-statistic):               0.00
# Time:                        14:24:32   Log-Likelihood:                -13560.
# No. Observations:               12427   AIC:                         2.718e+04
# Df Residuals:                   12395   BIC:                         2.742e+04
# Df Model:                          31
# Covariance Type:            nonrobust
# =====================================================================================================================
#                                                         coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------
# Intercept                                             7.9679      0.063    125.844      0.000       7.844       8.092
# C(sexo, Treatment(1))[T.F]                           -0.7877      0.015    -53.667      0.000      -0.817      -0.759
# C(posse_de_veiculo, Treatment(1))[T.False]           -0.0436      0.014     -3.085      0.002      -0.071      -0.016
# C(posse_de_imovel)[T.True]                            0.0829      0.014      5.917      0.000       0.055       0.110
# C(tipo_renda)[T.Bolsista]                             0.2256      0.241      0.936      0.349      -0.247       0.698
# C(tipo_renda)[T.Empresário]                           0.1550      0.015     10.381      0.000       0.126       0.184
# C(tipo_renda)[T.Pensionista]                         -0.3098      0.241     -1.284      0.199      -0.783       0.163
# C(tipo_renda)[T.Servidor público]                     0.0552      0.022      2.481      0.013       0.012       0.099
# C(educacao, Treatment(2))[T.Primário]                 0.0131      0.072      0.181      0.856      -0.128       0.154
# C(educacao, Treatment(2))[T.Pós graduação]            0.1189      0.142      0.836      0.403      -0.160       0.398
# C(educacao, Treatment(2))[T.Superior completo]        0.1070      0.014      7.688      0.000       0.080       0.134
# C(educacao, Treatment(2))[T.Superior incompleto]     -0.0290      0.032     -0.899      0.369      -0.092       0.034
# C(estado_civil)[T.Separado]                           0.3283      0.111      2.949      0.003       0.110       0.547
# C(estado_civil)[T.Solteiro]                           0.2665      0.109      2.437      0.015       0.052       0.481
# C(estado_civil)[T.União]                             -0.0339      0.025     -1.346      0.178      -0.083       0.015
# C(estado_civil)[T.Viúvo]                              0.3652      0.116      3.144      0.002       0.138       0.593
# C(tipo_residencia, Treatment(0))[T.Casa]             -0.0424      0.054     -0.782      0.434      -0.149       0.064
# C(tipo_residencia, Treatment(0))[T.Com os pais]      -0.0234      0.060     -0.388      0.698      -0.142       0.095
# C(tipo_residencia, Treatment(0))[T.Comunitário]      -0.1179      0.106     -1.112      0.266      -0.326       0.090
# C(tipo_residencia, Treatment(0))[T.Estúdio]           0.0659      0.099      0.663      0.507      -0.129       0.261
# C(tipo_residencia, Treatment(0))[T.Governamental]    -0.0537      0.066     -0.814      0.416      -0.183       0.076
# C(qt_pessoas_residencia, Treatment(2))[T.1.0]        -0.2825      0.109     -2.585      0.010      -0.497      -0.068
# C(qt_pessoas_residencia, Treatment(2))[T.3.0]         0.3136      0.110      2.849      0.004       0.098       0.529
# C(qt_pessoas_residencia, Treatment(2))[T.4.0]         0.6189      0.218      2.833      0.005       0.191       1.047
# C(qt_pessoas_residencia, Treatment(2))[T.5.0]         0.7581      0.331      2.290      0.022       0.109       1.407
# C(qt_pessoas_residencia, Treatment(2))[T.6.0]         1.4472      0.468      3.094      0.002       0.530       2.364
# C(qt_pessoas_residencia, Treatment(2))[T.7.0]         1.6595      0.909      1.826      0.068      -0.121       3.441
# C(qt_pessoas_residencia, Treatment(2))[T.9.0]         1.9122      0.828      2.310      0.021       0.290       3.535
# C(qt_pessoas_residencia, Treatment(2))[T.15.0]        2.7997      1.509      1.856      0.063      -0.157       5.757
# qtd_filhos                                           -0.2669      0.109     -2.450      0.014      -0.480      -0.053
# idade                                                 0.0056      0.001      6.897      0.000       0.004       0.007
# tempo_emprego                                         0.0616      0.001     59.268      0.000       0.060       0.064
# ==============================================================================
# Omnibus:                        1.118   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.572   Jarque-Bera (JB):                1.092
# Skew:                           0.021   Prob(JB):                        0.579
# Kurtosis:                       3.017   Cond. No.                     1.24e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.24e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# <h3 style="color:green">A variável menos relevente me parece ser a que indica o tipo de residencia, já que todas as suas categorias apresentam valor superior a 5% para o p-value, portanto, iremos removê-la</h3>

# %%
y, x = patsy.dmatrices('np.log(renda) ~ C(sexo, Treatment(1)) + C(posse_de_veiculo, Treatment(1)) + C(posse_de_imovel) + qtd_filhos + C(tipo_renda) + C(educacao, Treatment(2)) + C(estado_civil) + idade + tempo_emprego + C(qt_pessoas_residencia, Treatment(2))'
                       , data = df)

# %%
reg = sm.OLS(y, x).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          np.log(renda)   R-squared:                       0.358
# Model:                            OLS   Adj. R-squared:                  0.357
# Method:                 Least Squares   F-statistic:                     266.0
# Date:                Fri, 07 Jun 2024   Prob (F-statistic):               0.00
# Time:                        14:24:32   Log-Likelihood:                -13562.
# No. Observations:               12427   AIC:                         2.718e+04
# Df Residuals:                   12400   BIC:                         2.738e+04
# Df Model:                          26
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                            7.9316      0.037    216.861      0.000       7.860       8.003
# C(sexo, Treatment(1))[T.F]                          -0.7896      0.015    -53.941      0.000      -0.818      -0.761
# C(posse_de_veiculo, Treatment(1))[T.False]          -0.0437      0.014     -3.090      0.002      -0.071      -0.016
# C(posse_de_imovel)[T.True]                           0.0818      0.014      5.951      0.000       0.055       0.109
# C(tipo_renda)[T.Bolsista]                            0.2267      0.241      0.940      0.347      -0.246       0.699
# C(tipo_renda)[T.Empresário]                          0.1554      0.015     10.425      0.000       0.126       0.185
# C(tipo_renda)[T.Pensionista]                        -0.3130      0.241     -1.297      0.195      -0.786       0.160
# C(tipo_renda)[T.Servidor público]                    0.0564      0.022      2.540      0.011       0.013       0.100
# C(educacao, Treatment(2))[T.Primário]                0.0087      0.072      0.121      0.904      -0.132       0.149
# C(educacao, Treatment(2))[T.Pós graduação]           0.1174      0.142      0.825      0.409      -0.161       0.396
# C(educacao, Treatment(2))[T.Superior completo]       0.1067      0.014      7.684      0.000       0.079       0.134
# C(educacao, Treatment(2))[T.Superior incompleto]    -0.0288      0.032     -0.893      0.372      -0.092       0.034
# C(estado_civil)[T.Separado]                          0.3292      0.111      2.957      0.003       0.111       0.547
# C(estado_civil)[T.Solteiro]                          0.2679      0.109      2.450      0.014       0.054       0.482
# C(estado_civil)[T.União]                            -0.0327      0.025     -1.297      0.195      -0.082       0.017
# C(estado_civil)[T.Viúvo]                             0.3644      0.116      3.137      0.002       0.137       0.592
# C(qt_pessoas_residencia, Treatment(2))[T.1.0]       -0.2824      0.109     -2.585      0.010      -0.496      -0.068
# C(qt_pessoas_residencia, Treatment(2))[T.3.0]        0.3139      0.110      2.852      0.004       0.098       0.530
# C(qt_pessoas_residencia, Treatment(2))[T.4.0]        0.6181      0.218      2.829      0.005       0.190       1.046
# C(qt_pessoas_residencia, Treatment(2))[T.5.0]        0.7555      0.331      2.283      0.022       0.107       1.404
# C(qt_pessoas_residencia, Treatment(2))[T.6.0]        1.4439      0.468      3.088      0.002       0.527       2.361
# C(qt_pessoas_residencia, Treatment(2))[T.7.0]        1.5790      0.904      1.747      0.081      -0.192       3.350
# C(qt_pessoas_residencia, Treatment(2))[T.9.0]        1.9076      0.828      2.305      0.021       0.285       3.530
# C(qt_pessoas_residencia, Treatment(2))[T.15.0]       2.7910      1.508      1.850      0.064      -0.166       5.748
# qtd_filhos                                          -0.2664      0.109     -2.447      0.014      -0.480      -0.053
# idade                                                0.0055      0.001      6.862      0.000       0.004       0.007
# tempo_emprego                                        0.0616      0.001     59.357      0.000       0.060       0.064
# ==============================================================================
# Omnibus:                        1.070   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.586   Jarque-Bera (JB):                1.048
# Skew:                           0.021   Prob(JB):                        0.592
# Kurtosis:                       3.015   Cond. No.                     1.24e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.24e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# <h3 style="color:green">Até o momento, o modelo permaneceu sem alterações, somente as categorias apresentaram alterações em termos de seus p-values. Vamos seguir removendo algumas variáveis que não são relevantes para o modelo e observar possíveis melhorias</h3>

# %%
y, x = patsy.dmatrices('np.log(renda) ~ C(sexo, Treatment(1)) + C(posse_de_veiculo, Treatment(1)) + C(posse_de_imovel) + C(tipo_renda) + C(educacao, Treatment(2)) + C(estado_civil) + idade + tempo_emprego + C(qt_pessoas_residencia, Treatment(2))'
                       , data = df)

# %%
reg = sm.OLS(y, x).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          np.log(renda)   R-squared:                       0.358
# Model:                            OLS   Adj. R-squared:                  0.356
# Method:                 Least Squares   F-statistic:                     276.3
# Date:                Fri, 07 Jun 2024   Prob (F-statistic):               0.00
# Time:                        15:01:39   Log-Likelihood:                -13565.
# No. Observations:               12427   AIC:                         2.718e+04
# Df Residuals:                   12401   BIC:                         2.737e+04
# Df Model:                          25
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                            7.9282      0.037    216.876      0.000       7.857       8.000
# C(sexo, Treatment(1))[T.F]                          -0.7894      0.015    -53.919      0.000      -0.818      -0.761
# C(posse_de_veiculo, Treatment(1))[T.False]          -0.0434      0.014     -3.068      0.002      -0.071      -0.016
# C(posse_de_imovel)[T.True]                           0.0819      0.014      5.961      0.000       0.055       0.109
# C(tipo_renda)[T.Bolsista]                            0.2268      0.241      0.940      0.347      -0.246       0.699
# C(tipo_renda)[T.Empresário]                          0.1551      0.015     10.402      0.000       0.126       0.184
# C(tipo_renda)[T.Pensionista]                        -0.3160      0.241     -1.310      0.190      -0.789       0.157
# C(tipo_renda)[T.Servidor público]                    0.0567      0.022      2.551      0.011       0.013       0.100
# C(educacao, Treatment(2))[T.Primário]                0.0093      0.072      0.130      0.897      -0.131       0.150
# C(educacao, Treatment(2))[T.Pós graduação]           0.1144      0.142      0.804      0.421      -0.165       0.393
# C(educacao, Treatment(2))[T.Superior completo]       0.1063      0.014      7.657      0.000       0.079       0.134
# C(educacao, Treatment(2))[T.Superior incompleto]    -0.0284      0.032     -0.880      0.379      -0.092       0.035
# C(estado_civil)[T.Separado]                          0.0708      0.035      2.012      0.044       0.002       0.140
# C(estado_civil)[T.Solteiro]                          0.0137      0.034      0.401      0.688      -0.053       0.081
# C(estado_civil)[T.União]                            -0.0328      0.025     -1.302      0.193      -0.082       0.017
# C(estado_civil)[T.Viúvo]                             0.1082      0.050      2.153      0.031       0.010       0.207
# C(qt_pessoas_residencia, Treatment(2))[T.1.0]       -0.0281      0.034     -0.836      0.403      -0.094       0.038
# C(qt_pessoas_residencia, Treatment(2))[T.3.0]        0.0482      0.018      2.699      0.007       0.013       0.083
# C(qt_pessoas_residencia, Treatment(2))[T.4.0]        0.0866      0.023      3.789      0.000       0.042       0.131
# C(qt_pessoas_residencia, Treatment(2))[T.5.0]       -0.0429      0.055     -0.779      0.436      -0.151       0.065
# C(qt_pessoas_residencia, Treatment(2))[T.6.0]        0.3785      0.170      2.220      0.026       0.044       0.713
# C(qt_pessoas_residencia, Treatment(2))[T.7.0]        0.2482      0.722      0.344      0.731      -1.167       1.663
# C(qt_pessoas_residencia, Treatment(2))[T.9.0]        0.0431      0.323      0.133      0.894      -0.590       0.677
# C(qt_pessoas_residencia, Treatment(2))[T.15.0]      -0.6806      0.512     -1.330      0.183      -1.684       0.322
# idade                                                0.0056      0.001      6.944      0.000       0.004       0.007
# tempo_emprego                                        0.0616      0.001     59.327      0.000       0.060       0.064
# ==============================================================================
# Omnibus:                        1.054   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.591   Jarque-Bera (JB):                1.027
# Skew:                           0.020   Prob(JB):                        0.599
# Kurtosis:                       3.019   Cond. No.                     4.75e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.75e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# <h3 style="color:green">Mesmo com algumas dessas alterações, o modelo permaneceu o mesmo</h3>
